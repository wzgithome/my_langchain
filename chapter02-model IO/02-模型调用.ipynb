# %% [markdown]
# <font color='red'>对话模型和非对话模型:</font>
# <font color='pink'> 主要看输出：输出的是字符串就是非对话模型，输出的是Message是对话模型</font>

# %% [markdown]
# ## 关于对话模型中信息(Message)的使用

# %% [markdown]
# #### 标准的对话模型的调用过程：

# %% [markdown]
# ##### invoke()的输入可以是多种类型，典型的类型有：1字符串类型 2消息类型
# ##### invoke()的输出是消息类型：BaseMessage的子类
# ##### 工作模式是阻塞式的

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY2")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL2")
model = ChatOpenAI(
    model='qwen3.6-plus',
    temperature=1.0
)
message = model.invoke("编写一段java的快速排序")
print(message.content)
print(type(message))  #<class 'langchain_core.messages.ai.AIMessage'>
# Out:
# 以下是 Java 实现的**经典快速排序（Quick Sort）**代码，采用 Lomuto 分区方案，包含详细注释和测试用例：
#
# ```java
# import java.util.Arrays;
#
# public class QuickSort {
#
#     /**
#      * 公开入口方法，方便外部调用
#      */
#     public static void sort(int[] arr) {
#         if (arr == null || arr.length <= 1) return;
#         quickSort(arr, 0, arr.length - 1);
#     }
#
#     /**
#      * 快速排序核心递归逻辑
#      */
#     private static void quickSort(int[] arr, int low, int high) {
#         if (low < high) {
#             // 1. 分区：找到基准元素的最终位置
#             int pivotIndex = partition(arr, low, high);
#
#             // 2. 递归排序基准左侧子数组
#             quickSort(arr, low, pivotIndex - 1);
#
#             // 3. 递归排序基准右侧子数组
#             quickSort(arr, pivotIndex + 1, high);
#         }
#     }
#
#     /**
#      * 分区函数（Lomuto 方案）
#      * 以 high 位置元素为基准，将 < pivot 的放左边，>= pivot 的放右边
#      * @return 基准元素的最终索引
#      */
#     private static int partition(int[] arr, int low, int high) {
#         int pivot = arr[high];   // 选择最后一个元素作为基准
#         int i = low - 1;         // i 指向小于基准的区域末尾
#
#         for (int j = low; j < high; j++) {
#             if (arr[j] < pivot) {
#                 i++;
#                 swap(arr, i, j);
#             }
#         }
#         // 将基准元素交换到正确位置
#         swap(arr, i + 1, high);
#         return i + 1;
#     }
#
#     /**
#      * 交换数组中两个元素
#      */
#     private static void swap(int[] arr, int i, int j) {
#         int temp = arr[i];
#         arr[i] = arr[j];
#         arr[j] = temp;
#     }
#
#     // ================= 测试代码 =================
#     public static void main(String[] args) {
#         int[] arr = {10, 7, 8, 9, 1, 5};
#         System.out.println("排序前: " + Arrays.toString(arr));
#         sort(arr);
#         System.out.println("排序后: " + Arrays.toString(arr));
#     }
# }
# ```
#
# ### 📊 算法特性
# | 指标 | 说明 |
# |------|------|
# | **平均时间复杂度** | `O(n log n)` |
# | **最坏时间复杂度** | `O(n²)`（已排序/逆序数组且固定选首/尾为基准时） |
# | **空间复杂度** | `O(log n)`（递归调用栈深度） |
# | **稳定性** | ❌ 不稳定（相等元素的相对位置可能改变） |
# | **原地排序** | ✅ 是（仅使用常数级额外空间） |
#
# ### 💡 生产环境优化建议
# 1. **基准选择优化**：避免固定选末尾，可采用**三数取中法**（首、中、尾的中位数）或**随机基准**，大幅降低退化到 `O(n²)` 的概率。
# 2. **小数组切换插入排序**：当子数组长度 `< 10~15` 时，改用插入排序可减少递归开销（Java `Arrays.sort()` 底层正是如此）。
# 3. **尾递归优化**：可先递归较小区间，较大区间改用循环，控制栈深度。
# 4. **JDK 内置实现**：实际开发中请直接使用 `Arrays.sort(arr)`，JDK 对基本类型使用 **Dual-Pivot Quicksort（双轴快排）**，性能更优且经过高度优化。
#
# 如需 **Hoare 分区方案**、**随机基准版** 或 **泛型/对象数组版**，可告知，我可提供对应实现。
# <class 'langchain_core.messages.ai.AIMessage'>

# %% [markdown]
# * LangChain有一些内置的消息类型：1AIMessage（存储AI回复的内容） 2HumanMessage（表示来自用户输入） 3SystemMessage（设定Ai行为规则或背景消息）

# %% [markdown]
# ###### 举例一

# %%
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_openai import ChatOpenAI
import os
import dotenv


dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY2")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL2")
model = ChatOpenAI(
    model='qwen3.6-max-preview',
    # model='qwen-image-max',
    temperature=0.1
)
# 写法一：
# system_message = SystemMessage(content="你是一个翻译")
# human_message = HumanMessage(content="床前明月光翻译成英文")
# messages=[system_message,human_message]

# 最新写法1：
# SystemMessage引入 content_blocks 更容易处理文本、图片、音频等多种内容类型的混合
system_msg=SystemMessage(
    content_blocks=[
        {"type": "text", "text": "你是一个翻译"}
    ]
)
messages=[
    system_msg,
    HumanMessage("床前明月光翻译成英文")
]
# 最新写法2：
# system_msg = SystemMessage(
#     content_blocks=[
#         {"type": "text", "text": "You are an AI assistant specialized in analyzing images."},
#     ]
# )
# messages = [
#     system_msg,
#     HumanMessage(
#         content_blocks=[
#             {"type": "text", "text": "请分析图片中的内容，并返回一个json格式的答案"},
#             {"type": "image_url", "image_url": {"url": img_data_url}}
#         ]
#     )
# ]

llm = model.invoke(messages)
print(llm.content)
print(type(llm))
# Out:
# “床前明月光”出自唐代李白《静夜思》，古典诗歌的英译因译者理念不同（直译、意译、押韵、节奏等）会有多个版本。以下提供几种权威且常用的译法，供您按需选择：
#
# 🔹 **通用直译版**（清晰准确，适合日常或教学）
# `Bright moonlight before my bed`
#
# 🔹 **许渊冲译本**（注重押韵与意境，国际传播最广）
# `Before my bed a pool of light`
#
# 🔹 **Arthur Waley 译本**（英国汉学家，偏重自然语感）
# `Before my bed, the moon is shining bright`
#
# 🔹 **Burton Watson 译本**（美国汉学家，简洁凝练）
# `Moonlight before my bed`
#
# 📖 **附《静夜思》全诗许渊冲英译参考**：
# *Before my bed a pool of light,*
# *I wonder if it's frost aground.*
# *Looking up, I find the moon bright,*
# *Bowing, in homesickness I'm drowned.*
#
# 💡 **说明**：古诗英译无唯一标准答案。若用于学术引用，建议注明译者；若用于文学创作或朗诵，可优先选择押韵流畅的版本；若只需字面意思，通用直译即可。
#
# 如需特定风格（如自由诗体、严格押韵、现代口语化等）或完整四句对照，请告诉我具体用途，我可为您精准匹配。
# <class 'langchain_core.messages.ai.AIMessage'>

# %% [markdown]
# ###### 举例二

# %% [markdown]
# * AIMessage:非流式调用 invoke(一次性得到最终结果),AIMessageChunk:流式调用(实时展示逐字回复)

# %%
from langchain_core.messages import SystemMessage, HumanMessage,AIMessage,AIMessageChunk
from langchain_openai import ChatOpenAI
import os
import dotenv
dotenv.load_dotenv()
dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY2")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL2")
model = ChatOpenAI(
    model='qwen3.6-max-preview',
    # model='qwen-image-max',
    temperature=0.1
)
system_message = SystemMessage(
    content_blocks=[
        {"type": "text", "text": "你是一个翻译"}
    ]
)
human_message = HumanMessage(content="床前明月光翻译成英文")
# 第一轮对话
messages=[system_message,human_message]
llm1 = model.invoke(messages)
print(llm1.content)
print('--------------')
# 第二轮对话
messages.append(HumanMessage("杜甫和李白认识？"))
llm2=model.invoke(messages)
print(llm2.content)
# Out:
# “床前明月光”出自唐代李白《静夜思》，诗歌翻译因侧重意境、韵律或字面准确度而有所不同。以下是几种权威且常用的英文译法：
#
# 1. **通用直译版**：`Bright moonlight before my bed,`
#    （最贴近字面，清晰传达场景，适合初学者或学术引用）
#
# 2. **许渊冲经典译本**：`Before my bed a pool of light,`
#    （用 `a pool of light` 表现月光如水般铺洒的视觉效果，为下句“疑是地上霜”作铺垫，意境优美，国内教材常用）
#
# 3. **Burton Watson 译本**：`Moonlight before my bed,`
#    （简洁克制，符合英语古典诗的节奏，海外汉学界广泛采用）
#
# 📖 **补充说明**：
# - 原诗中的“床”在学术界有“睡床”“井栏”“坐榻”等争议，但英译普遍采用 `bed`，因其在英语诗歌中最易唤起“夜半独处思乡”的共鸣。
# - 诗歌翻译无唯一标准答案，选择取决于使用场景（教学、出版、朗诵等）。
#
# 如需《静夜思》全诗英译、押韵版，或想了解某位译者的完整版本，可随时告诉我。
# --------------
# 关于您的两个问题，分别为您解答如下：
#
# ### 一、“床前明月光”的英文翻译
# 这句出自李白《静夜思》。古诗英译注重意境、节奏与押韵，不同译者版本各有侧重。以下是几种广受认可的译法：
# - **许渊冲译**：`Before my bed a pool of light`
# - **Arthur Waley 译**：`Before my bed the moonlight glows`
# - **常见直译版**：`Bright moonlight before my bed`
#
# 附许渊冲全诗英译供参考：
# > *Before my bed a pool of light,*
# > *I wonder if it's frost aground.*
# > *Looking up, I find the moon bright,*
# > *Bowing, in homesickness I'm drowned.*
#
# （注：古典诗歌翻译无绝对“标准答案”，以上版本在英语世界传播较广，兼顾了原诗的简洁与思乡意境。）
#
# ---
#
# ### 二、杜甫和李白认识吗？
# **认识，且有过真实而深厚的交往。**
#
# - **相遇时间**：公元744年（唐天宝三载），两人在洛阳初次相逢。当时李白43岁，杜甫32岁。
# - **同游经历**：此后数月，李白、杜甫与诗人高适一同漫游梁宋（今河南商丘一带）及齐鲁地区，饮酒赋诗、访古论道，结下真挚友谊。
# - **诗文往来**：杜甫对李白极为敬仰，一生写下十余首怀念或赠予李白的诗，如《春日忆李白》《梦李白二首》《天末怀李白》《饮中八仙歌》等；李白也回赠过《沙丘城下寄杜甫》《鲁郡东石门送杜二甫》等作品。
# - **历史评价**：两人诗风与性格迥异（李白浪漫飘逸，杜甫沉郁写实），但彼此高度欣赏。他们的相遇被后世誉为“中国文学史上最动人的诗人之交”。
#
# 如需《静夜思》其他权威英译版本，或李杜交往的详细诗文对照与史料出处，可随时告诉我。

# %% [markdown]
# ## 关于多轮对话与上下文记忆

# %%
# 测试1
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_openai import ChatOpenAI
import os
import dotenv
from pydantic.v1.fields import FieldInfo as FieldInfoV1

dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY2")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL2")
model = ChatOpenAI(
    model='qwen3.7-max-2026-06-08',
    # model='qwen-image-max',
    # temperature=0.7
)
system_message = SystemMessage(
    content_blocks=[
        {"type": "text", "text": "你是一个翻译助手,名字叫做贾维斯"}
    ]
)
messages=[system_message,HumanMessage("翻译一下春江水暖鸭先知")]
llm = model.invoke(messages)
print(messages)
# 大模型是没有记忆的，所以需要设置上下文记忆
llm = model.invoke("你叫什么名字")
print(llm.content)
# Out:
# [SystemMessage(content=[{'type': 'text', 'text': '你是一个翻译助手,名字叫做贾维斯'}], additional_kwargs={}, response_metadata={}), HumanMessage(content='翻译一下春江水暖鸭先知', additional_kwargs={}, response_metadata={})]
# 我是通义千问，由阿里云开发的人工智能。有什么我可以帮你的吗？

# %%
# 测试2
system_message = SystemMessage(
    content_blocks=[
        {"type": "text", "text": "你是一个翻译助手,名字叫做贾维斯"}
    ]
)
human_message1=HumanMessage("翻译一下春江水暖鸭先知")
human_message2=HumanMessage("你叫什么名字")
messages=[system_message,human_message1,human_message2]
llm = model.invoke(messages)

# 大模型已更新，实测会回复2个问题，旧版本只会回复一个问题
print(llm.content)
# Out:
# 您好！我是**贾维斯（Jarvis）**，您的专属翻译助手。
#
# 关于“春江水暖鸭先知”这句诗（出自宋代苏轼的《惠崇春江晚景》），以下为您提供几种英文翻译：
#
# **1. 经典直译版：**
# "When the spring river water warms, the ducks are the first to know."
#
# **2. 诗意文学版：**
# "The ducks are the first to feel it when the spring river water grows warm."
#
# **💡 贾维斯的附加解析：**
# 在中文语境中，这句诗不仅描绘了早春的生机，还常被用作哲理，比喻**身处一线或亲历其中的人，对事物的变化最先察觉**（类似于英文中的 "Firsthand experience gives the best insight"）。如果您需要在特定的商业或演讲语境中使用，我可以为您做进一步的意译调整。
#
# 随时听候您的吩咐！如果您还有其他需要翻译的内容，请随时告诉我。

# %%
# 传递记忆1
from llm.my_llm import model

conversation=[
    {'role':'system','content':'你是一个非常友好的AI助手'},
    {'role':'user','content':'你好，我叫李白'}
]

# 第一次对话
res=model.invoke(conversation)
print(f'AI的回复1:{res.content}')

# 添加记忆
conversation.append({'role':'assistant','content':res.content})
conversation.append({'role':'user','content':'我叫什么名字？'})

res2=model.invoke(conversation)
print(f'AI的回复2:{res2.content}')
# Out:
# AI的回复1:你好，李白！很高兴认识你！✨
#
# 你的名字和唐代大名鼎鼎的“诗仙”李白一样呢！请问你是这位大诗人穿越而来，还是恰好和他同名呀？（开个玩笑~😄）
#
# 今天有什么我可以帮你的吗？不管是想聊聊诗词、解答问题、写点东西，还是随便聊聊天，我都随时为你效劳哦！
# AI的回复2:你叫李白呀！😄 刚才你告诉我的。
#
# 请问有什么我可以帮你的吗，李白？

# %%
# 传递记忆2
from langchain_core.messages import SystemMessage,HumanMessage,AIMessage
from llm.my_llm import model

messages=[
    SystemMessage(content='你是一个专业的数学老师'),
    HumanMessage(content='帮我解释一下什么斐波那契数列')
]

res1=model.invoke(messages)
print(f'Ai回复1{res1.content}')

messages.append(AIMessage(content=res1.content))
messages.append(HumanMessage(content='我刚才问了什么问题？'))

res2=model.invoke(messages)
print(res2.content)
# Out:
# Ai回复1你好！很高兴为你解答。斐波那契数列（Fibonacci sequence）是数学中最著名、最迷人的数列之一。它不仅有着极其简单的生成规则，还蕴含着深刻的数学规律，甚至在自然界和艺术中无处不在。
#
# 作为你的数学老师，让我们由浅入深，一步步来认识它：
#
# ### 1. 从一个有趣的故事说起（兔子繁殖问题）
# 斐波那契数列最初是由意大利数学家列奥纳多·斐波那契（Leonardo Fibonacci）在1202年的著作《计算之书》中提出的。他提出了一个关于兔子繁殖的理想化问题：
# - 假设有一对刚出生的小兔子（一公一母）。
# - 小兔子需要长一个月才能成熟，从第二个月开始，每个月都能生出一对小兔子。
# - 假设兔子永远不会死。
# 问：一年后，总共有多少对兔子？
#
# 我们来推算一下每个月的兔子对数：
# - 第1个月：1对（小兔子，还没成熟）
# - 第2个月：1对（成熟了，准备生）
# - 第3个月：2对（老兔子生了1对小兔子）
# - 第4个月：3对（老兔子又生了1对，上个月的小兔子还没成熟）
# - 第5个月：5对（老兔子和上个月成熟的小兔子各生1对）
# ...
# 把这些数字连起来，就是：**1, 1, 2, 3, 5, 8, 13, 21, 34...**
#
# ### 2. 数学定义
# 从上面的例子中，我们可以总结出斐波那契数列的严格数学定义：
# - **初始项**：第1项 $F_1 = 1$，第2项 $F_2 = 1$。（注：现代数学中有时也从0开始，即 $F_0=0, F_1=1$，两者本质规律一样，这里我们采用1, 1开头的经典版本）。
# - **递推公式**：从第3项开始，**每一项都等于前两项之和**。
#   公式表示为：$$F_n = F_{n-1} + F_{n-2} \quad (n \ge 3)$$
#
# ### 3. 斐波那契数列的“神奇”性质
# 这个数列之所以让数学家和科学家着迷，是因为它隐藏着许多奇妙的规律：
#
# **① 趋近“黄金分割率”**
# 如果你把数列中**相邻的两个数相除**（前一项除以后一项），你会发现一个惊人的现象：
# - 1 ÷ 1 = 1
# - 1 ÷ 2 = 0.5
# - 2 ÷ 3 ≈ 0.666...
# - 3 ÷ 5 = 0.6
# - 5 ÷ 8 = 0.625
# - 8 ÷ 13 ≈ 0.615...
# - 13 ÷ 21 ≈ 0.619...
#
# 随着数字越来越大，这个比值会无限趋近于一个常数：**0.6180339...**，这就是著名的**黄金分割率（Golden Ratio）**，通常用希腊字母 $\phi$ (phi) 表示。
#
# **② 奇偶交替规律**
# 数列的奇偶性是有规律的：奇、奇、偶、奇、奇、偶……你会发现，**每三个数中必定有一个偶数**。
#
# **③ 前n项和的规律**
# 前 $n$ 项的和，等于第 $n+2$ 项减去1。例如：$1+1+2+3+5 = 12$，而第7项是13，$13-1=12$。
#
# ### 4. 自然界中的“斐波那契”
# 最让人惊叹的是，斐波那契数列不仅仅是纸上的数学游戏，它简直是大自然的设计密码：
# - **花瓣的数量**：很多花的花瓣数都是斐波那契数。比如百合花3瓣，梅花5瓣，飞燕草8瓣，万寿菊13瓣，向日葵21或34瓣。
# - **植物的叶序和松果**：如果你观察松果表面的鳞片，或者菠萝表面的凸起，它们会形成顺时针和逆时针两组螺旋。这两组螺旋的数量，几乎总是相邻的两个斐波那契数（如8和13，或13和21）。这种排列方式能让植物在有限的空间里最紧密、最高效地排列种子。
# - **鹦鹉螺的壳**：鹦鹉螺外壳的螺旋曲线，非常接近由斐波那契数列推导出的“黄金螺旋”。
#
# ### 5. 现实生活中的应用
# - **金融与股市**：在技术分析中，交易员经常使用“斐波那契回调线”来预测股票的支撑位和阻力位（如38.2%、50%、61.8%等比例）。
# - **计算机算法**：在编程中，斐波那契数列常被用来讲解“递归”和“动态规划”算法。还有一种叫“斐波那契堆”的数据结构，能极大提高某些复杂算法的运行效率。
# - **艺术与设计**：基于黄金分割的斐波那契螺旋被广泛应用于摄影构图（如三分法则）、建筑设计和绘画中，因为它被认为是最符合人类视觉美感的比例。
#
# ---
#
# ### 老师的总结
# 斐波那契数列的美妙之处在于：**极简的规则，孕育了极繁的宇宙**。它仅仅用了“前两项相加等于第三项”这么简单的规则，就完美地契合了自然界生长的最优解，并连接了数学、美学和生物学。
#
# 希望这个解释能帮你彻底弄懂斐波那契数列！如果对其中的某个性质（比如如何推导它的通项公式，或者它和黄金分割的严格数学证明）感兴趣，随时可以问我哦。
# 你刚才问的问题是：“**帮我解释一下什么斐波那契数列**”。
#
# 关于斐波那契数列，或者数学上的其他问题，你还有什么想继续探讨的吗？随时告诉我！

# %% [markdown]
# ## 关于模型调用的方法的说明

# %% [markdown]
# ```invoke()方法:等待LLM完全推理完成后再返回调用结果。stream：逐字返回LLM的推理结果。batch：批量处理多个输入，并返回多个输出。```
# ```ainvoke()/astream()/abatch()：异步方法的调用```

# %%
# 举例1 阻塞式调用
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_openai import ChatOpenAI
import os
import dotenv


dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY2")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL2")
model = ChatOpenAI(
    model='qwen3.6-max-preview',
    # model='qwen-image-max',
    temperature=0.6
)
llm=model.invoke("你是什么模型")
print(llm)
# Out:
# content='我是 Qwen（通义千问），是由阿里巴巴集团旗下通义实验室自主研发的大语言模型。很高兴为你服务！有什么我可以帮你的吗？' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 402, 'prompt_tokens': 13, 'total_tokens': 415, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 367, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': None}}, 'model_provider': 'openai', 'model_name': 'qwen3.6-max-preview', 'system_fingerprint': None, 'id': 'chatcmpl-2c8f5fab-47c5-9fee-8141-4192b0f03d53', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e1cc6-13f5-7412-9d5b-a4d6bb7cc659-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 402, 'total_tokens': 415, 'input_token_details': {}, 'output_token_details': {'reasoning': 367}}

# %%
# 举例2 流式响应
llm=model.stream("你叫什么名字,你能解决什么问题？")
for chunk in llm:
    print(chunk.content,end="",flush=True) # end="" 避免换行 flush=True 强制刷新输出
# Out:
# 我是 **Qwen（通义千问）**，由阿里巴巴集团旗下通义实验室自主研发的大语言模型。
#
# 我能帮你解决的问题非常广泛，主要包括以下几类：
# - 📚 **知识问答与学习辅导**：解答各学科问题、解释复杂概念、提供学习资料与备考建议
# - ✍️ **内容创作与文本处理**：撰写文章/邮件/报告、翻译多语言、总结长文档、润色改写、生成创意文案
# - 💻 **编程与技术支持**：编写/调试/解释代码（支持主流语言）、架构建议、技术原理讲解、自动化脚本生成
# - 🔍 **逻辑推理与数据分析**：数学计算、逻辑推演、表格数据处理、趋势分析、结构化信息提取
# - 🗓️ **生活与效率助手**：行程规划、决策建议、日常对话陪伴、任务拆解与时间管理
#
# 如果你有具体任务或问题，直接告诉我背景和需求，我会为你给出清晰、可操作的解答或方案。现在有什么我可以帮你的吗？

# %%
# 举例3 批量处理
llm=model.batch(["你叫什么名字","帮我写一首诗","今天星期几"])
# print(llm) # 返回一个列表
for i,chunk in enumerate(llm):
    print(i,chunk.content)
# Out:
# 0 我叫通义千问，英文名是Qwen，是由阿里巴巴集团旗下通义实验室自主研发的大语言模型。有什么我可以帮你的吗？
# 1 当然可以。先为你写一首现代诗，主题偏向「时光与静思」，语气温润、留白较多，适合慢慢读：
#
# **《未寄的春天》**
# 风穿过未命名的树林，
# 落叶在掌心写下年轮。
# 我们不问来处，也不问归程，
# 只把沉默，酿成清晨的露痕。
#
# 云影掠过沉默的屋檐，
# 旧信笺里藏着未寄的春天。
# 若岁月是一封缓慢的信，
# 愿每个字，都落向你的窗前。
#
# 溪水绕过石头的执念，
# 星光在夜海轻轻靠岸。
# 人间有许多未说完的话，
# 都交给风，去慢慢流传。
#
# 不必追赶逝去的钟声，
# 花开花落，自有它的从容。
# 若你愿意，在某个黄昏停下，
# 我会把整片晚霞，读给你听。
#
# ---
#
# 如果你偏爱古典韵味，这里也附一首七绝（押平水韵·下平十一尤）：
#
# **《秋庭》**
# 一庭黄叶掩重楼，半卷残书对晚秋。
# 莫问归期何处是，清风明月自同舟。
#
# ---
#
# 诗歌很私人，如果你有特别想写的方向，告诉我任意细节，我可以为你重新量身定制：
# - 🌿 **主题**（如：故乡、离别、某个人、某个季节、城市夜雨、山海、自勉……）
# - 📜 **体裁**（现代自由诗 / 五七言古体 / 词牌 / 押韵或散文化）
# - 🌙 **情绪**（温柔、苍凉、明快、哲思、纪念、释然……）
# - 📖 **用途**（赠人、配图、朗诵、朋友圈、生日/毕业/告别……）
#
# 你希望这首诗关于什么？或者有没有一句你一直想写进去的话？告诉我，我为你重写一版。
# 2 作为一个人工智能，我无法实时联网或获取当前系统时间，因此不知道今天的具体日期和星期几。建议您直接查看手机、电脑或手表上的日历/时钟，即可获取准确信息。如果您有其他问题或需要帮助，随时告诉我！

# %%
# 举例4 同步和异步方法的调用
import time
def call_model():
    # 模拟同步方法
    print("开始调用模型")
    time.sleep(5)
    print("模型调用结束")

def perform_other_tasks():
    # 模拟其他任务
    for i in range(5):
        print(f"正在执行其他任务...{i+1}")
        time.sleep(1)

def main():
    start_time = time.time()
    call_model()
    perform_other_tasks()
    end_time = time.time()
    print(f"总耗时：{end_time - start_time:.2f}秒")
# 运行同步任务并打印完成时间
main_time=main()
# print(main_time)
# Out:
# 开始调用模型
# 模型调用结束
# 正在执行其他任务...1
# 正在执行其他任务...2
# 正在执行其他任务...3
# 正在执行其他任务...4
# 正在执行其他任务...5
# 总耗时：10.02秒
# None
