# %% [markdown]
# ### 结构化输出：ProviderStrategy策略

# %%
"""
    1、原生结构化输出功能实现结构化输出
"""
from langchain_core.messages import HumanMessage
from pydantic import BaseModel, Field
from langchain.agents.structured_output import ProviderStrategy


from llm.my_llm import model
from rich import print as rprint
from langchain.agents import create_agent


class ContractInfo(BaseModel):
    """用户的联系方式"""
    name:str=Field(description='用户到姓名')
    email:str=Field(description='用户到邮箱')
    phone:str=Field(description='用户到电话')

agent=create_agent(
    model=model,
    response_format=ProviderStrategy(ContractInfo)
)

res=agent.invoke({
    "messages":[{'role':'user','content':'从以下信息中提取用户消息，小明的邮箱是asdasdad@163.com,电话是19966155502,以JSON格式输出'}]
})
rprint(res)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='从以下信息中提取用户消息，小明的邮箱是asdasdad@163.com,电话是19966155502,以JSON格式输出',
#             additional_kwargs={},
#             response_metadata={},
#             id='d3b52794-14bb-4971-92df-4290c735105c'
#         ),
#         AIMessage(
#             content='{\n  "name": "小明",\n  "email": "asdasdad@163.com",\n  "phone": "19966155502"\n}',
#             additional_kwargs={'parsed': None, 'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 551,
#                     'prompt_tokens': 50,
#                     'total_tokens': 601,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': None,
#                         'audio_tokens': None,
#                         'reasoning_tokens': 503,
#                         'rejected_prediction_tokens': None,
#                         'text_tokens': 551
#                     },
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': None, 'text_tokens': 50}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'qwen3.6-flash-2026-04-16',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-b5e716a3-5461-9ebe-8d8c-a8912e72c531',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019f3c03-a13f-74e1-a917-0c504a6d40f3-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 50,
#                 'output_tokens': 551,
#                 'total_tokens': 601,
#                 'input_token_details': {},
#                 'output_token_details': {'reasoning': 503}
#             }
#         )
#     ],
#     'structured_response': ContractInfo(name='小明', email='asdasdad@163.com', phone='19966155502')
# }

# %%
"""
    2、使用ToolStrategy结构化输出
    注意：ToolStrategy 会设置 tool_choice="required"，
    通义千问 thinking 模式不支持该参数，必须用 ChatOpenAI 走兼容接口并关闭 thinking
"""
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy
from rich import print as rprint
from pydantic import BaseModel, Field
from llm.my_llm import model_tool

class ContractInfo(BaseModel):
    """用户的联系方式"""
    name:str=Field(description='用户到姓名')
    email:str=Field(description='用户到邮箱')
    phone:str=Field(description='用户到电话')

# 用 ChatOpenAI 走 DashScope 兼容接口，extra_body 才能正确传递


agent=create_agent(
    model=model_tool,
    response_format=ToolStrategy(ContractInfo)
)

res=agent.invoke({
    "messages":[{'role':'user','content':'从以下信息中提取用户消息，小明的邮箱是asdasdad@163.com,电话是19966155502'}]
})
# rprint(res)
print(res['structured_response'])
# Out:
# name='小明' email='asdasdad@163.com' phone='19966155502'
